# %%
# %%writefile ../src/testing_magic_method.py

def foo():
    doc = "The foo property."
    def fget(self):
        return self._foo
    def fset(self, value):
        self._foo = value
    def fdel(self):
        del self._foo
    return locals()
foo = property(**foo())
# Out:
# Overwriting ../src/testing_magic_method.py
